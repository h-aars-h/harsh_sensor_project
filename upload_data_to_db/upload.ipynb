# %%
from pymongo.mongo_client import MongoClient
import pandas as pd 
import json

# %%
uri = "mongodb+srv://harsh:Harsh@atlascluster.9xpvtwc.mongodb.net/?retryWrites=true&w=majority"

# %%
# Create a new client and connect to the server
client = MongoClient(uri)
# create data base 
DATABASE_NAME='harsh'
COLLECTION_NAME='waferfault'

# %%
#  read data 
df=pd.read_csv(r'C:\Users\hknit\OneDrive\Desktop\PYTHON\sensor_project\notebook\wafer_23012020_041211.csv')

# %%
df
# Out:
#    Unnamed: 0  Sensor-1  Sensor-2   Sensor-3   Sensor-4  Sensor-5  Sensor-6
# 0   Wafer-801   2968.33   2476.58  2216.7333  1748.0885    1.1127     100.0  \
# 1   Wafer-802   2961.04   2506.43  2170.0666  1364.5157    1.5447     100.0
# 2   Wafer-803   3072.03   2500.68  2205.7445  1363.1048    1.0518     100.0
# 3   Wafer-804   3021.83   2419.83  2205.7445  1363.1048    1.0518     100.0
# 4   Wafer-805   3006.95   2435.34  2189.8111  1084.6502    1.1993     100.0
# ..        ...       ...       ...        ...        ...       ...       ...
# 95  Wafer-896   3013.66   2526.44  2185.2111  1141.6306    0.8447     100.0
# 96  Wafer-897   2982.87   2477.01  2315.2667  2360.1325    1.1259     100.0
# 97  Wafer-898   3084.82   2387.42  2171.5000  1028.4440    0.7899     100.0
# 98  Wafer-899   2955.87   2541.89        NaN        NaN       NaN       NaN
# 99  Wafer-900   2914.86   2465.11  2210.2778  2120.5760    1.0700     100.0
#
#     Sensor-7  Sensor-8  Sensor-9  ...  Sensor-582  Sensor-583  Sensor-584
# 0    97.5822    0.1242    1.5300  ...         NaN      0.5004      0.0120  \
# 1    96.7700    0.1230    1.3953  ...         NaN      0.4994      0.0115
# 2   101.8644    0.1220    1.3896  ...         NaN      0.4987      0.0118
# 3   101.8644    0.1220    1.4108  ...         NaN      0.4934      0.0123
# 4   104.8856    0.1234    1.5094  ...         NaN      0.4987      0.0145
# ..       ...       ...       ...  ...         ...         ...         ...
# 95  100.5978    0.1217    1.5337  ...         NaN      0.5013      0.0076
# 96   90.1144    0.1160    1.4695  ...         NaN      0.5003      0.0106
# 97  101.5122    0.1224    1.3603  ...         NaN      0.5016      0.0130
# 98       NaN       NaN    1.4493  ...         NaN      0.5023      0.0140
# 99   95.1089    0.1230    1.5817  ...         NaN      0.5026      0.0121
#
#     Sensor-585  Sensor-586  Sensor-587  Sensor-588  Sensor-589  Sensor-590
# 0       0.0033      2.4069      0.0545      0.0184      0.0055     33.7876  \
# 1       0.0031      2.3020      0.0545      0.0184      0.0055     33.7876
# 2       0.0036      2.3719      0.0545      0.0184      0.0055     33.7876
# 3       0.0040      2.4923      0.0545      0.0184      0.0055     33.7876
# 4       0.0041      2.8991      0.0545      0.0184      0.0055     33.7876
# ..         ...         ...         ...         ...         ...         ...
# 95      0.0021      1.5152      0.0153      0.0048      0.0017     31.0176
# 96      0.0028      2.1263      0.0153      0.0048      0.0017     31.0176
# 97      0.0028      2.5865      0.0153      0.0048      0.0017     31.0176
# 98      0.0033      2.7810      0.0153      0.0048      0.0017     31.0176
# 99      0.0032      2.4064      0.0153      0.0048      0.0017     31.0176
#
#     Good/Bad
# 0         -1
# 1          1
# 2         -1
# 3         -1
# 4         -1
# ..       ...
# 95        -1
# 96         1
# 97        -1
# 98        -1
# 99         1
#
# [100 rows x 592 columns]

# %%
df=df.drop('Unnamed: 0',axis=1)

# %%
json_record=list(json.loads(df.T.to_json()).values())

# %%
client[DATABASE_NAME][COLLECTION_NAME].insert_many(json_record)
# Out:
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 client[DATABASE_NAME][COLLECTION_NAME].insert_many(json_record)
#
# File c:\Users\hknit\OneDrive\Desktop\PYTHON\sensor_project\env\Lib\site-packages\pymongo\_csot.py:105, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     103         with _TimeoutContext(timeout):
#     104             return func(self, *args, **kwargs)
# --> 105 return func(self, *args, **kwargs)
#
# File c:\Users\hknit\OneDrive\Desktop\PYTHON\sensor_project\env\Lib\site-packages\pymongo\collection.py:707, in Collection.insert_many(self, documents, ordered, bypass_document_validation, session, comment)
#     705 blk = _Bulk(self, ordered, bypass_document_validation, comment=comment)
#     706 blk.ops = [doc for doc in gen()]
# --> 707 blk.execute(write_concern, session=session)
#     708 return InsertManyResult(inserted_ids, write_concern.acknowledged)
#
# File c:\Users\hknit\OneDrive\Desktop\PYTHON\sensor_project\env\Lib\site-packages\pymongo\bulk.py:513, in _Bulk.execute(self, write_concern, session)
#     511         self.execute_no_results(sock_info, generator, write_concern)
#     512 else:
# --> 513     return self.execute_command(generator, write_concern, session)
#
# File c:\Users\hknit\OneDrive\Desktop\PYTHON\sensor_project\env\Lib\site-packages\pymongo\bulk.py:390, in _Bulk.execute_command(self, generator, write_concern, session)
#     385     self._execute_command(
#     386         generator, write_concern, session, sock_info, op_id, retryable, full_result
#     387     )
#     389 client = self.collection.database.client
# --> 390 with client._tmp_session(session) as s:
#     391     client._retry_with_session(self.is_retryable, retryable_bulk, s, self)
#     393 if full_result["writeErrors"] or full_result["writeConcernErrors"]:
#
# File c:\Users\hknit\OneDrive\Desktop\PYTHON\sensor_project\env\Lib\contextlib.py:137, in _GeneratorContextManager.__enter__(self)
#     135 del self.args, self.kwds, self.func
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#     139     raise RuntimeError("generator didn't yield") from None
#
# File c:\Users\hknit\OneDrive\Desktop\PYTHON\sensor_project\env\Lib\site-packages\pymongo\mongo_client.py:1729, in MongoClient._tmp_session(self, session, close)
#    1726     yield session
#    1727     return
# -> 1729 s = self._ensure_session(session)
#    1730 if s:
#    1731     try:
#
# File c:\Users\hknit\OneDrive\Desktop\PYTHON\sensor_project\env\Lib\site-packages\pymongo\mongo_client.py:1712, in MongoClient._ensure_session(self, session)
#    1707     return session
#    1709 try:
#    1710     # Don't make implicit sessions causally consistent. Applications
#    1711     # should always opt-in.
# -> 1712     return self.__start_session(True, causal_consistency=False)
#    1713 except (ConfigurationError, InvalidOperation):
#    1714     # Sessions not supported.
#    1715     return None
#
# File c:\Users\hknit\OneDrive\Desktop\PYTHON\sensor_project\env\Lib\site-packages\pymongo\mongo_client.py:1657, in MongoClient.__start_session(self, implicit, **kwargs)
#    1654 def __start_session(self, implicit, **kwargs):
#    1655     # Raises ConfigurationError if sessions are not supported.
#    1656     if implicit:
# -> 1657         self._topology._check_implicit_session_support()
#    1658         server_session = _EmptyServerSession()
#    1659     else:
#
# File c:\Users\hknit\OneDrive\Desktop\PYTHON\sensor_project\env\Lib\site-packages\pymongo\topology.py:538, in Topology._check_implicit_session_support(self)
#     536 def _check_implicit_session_support(self):
#     537     with self._lock:
# --> 538         self._check_session_support()
#
# File c:\Users\hknit\OneDrive\Desktop\PYTHON\sensor_project\env\Lib\site-packages\pymongo\topology.py:554, in Topology._check_session_support(self)
#     550         self._select_servers_loop(
#     551             any_server_selector, self.get_server_selection_timeout(), None
#     552         )
#     553 elif not self._description.readable_servers:
# --> 554     self._select_servers_loop(
#     555         readable_server_selector, self.get_server_selection_timeout(), None
#     556     )
#     558 session_timeout = self._description.logical_session_timeout_minutes
#     559 if session_timeout is None:
#
# File c:\Users\hknit\OneDrive\Desktop\PYTHON\sensor_project\env\Lib\site-packages\pymongo\topology.py:238, in Topology._select_servers_loop(self, selector, timeout, address)
#     235 while not server_descriptions:
#     236     # No suitable servers.
#     237     if timeout == 0 or now > end_time:
# --> 238         raise ServerSelectionTimeoutError(
#     239             "%s, Timeout: %ss, Topology Description: %r"
#     240             % (self._error_message(selector), timeout, self.description)
#     241         )
#     243     self._ensure_opened()
#     244     self._request_check_all()
#
# ServerSelectionTimeoutError: ac-dxhyvys-shard-00-00.9xpvtwc.mongodb.net:27017: connection closed,ac-dxhyvys-shard-00-01.9xpvtwc.mongodb.net:27017: connection closed,ac-dxhyvys-shard-00-02.9xpvtwc.mongodb.net:27017: connection closed, Timeout: 30s, Topology Description: <TopologyDescription id: 64ac8045bdd2230913e5bc3b, topology_type: ReplicaSetNoPrimary, servers: [<ServerDescription ('ac-dxhyvys-shard-00-00.9xpvtwc.mongodb.net', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('ac-dxhyvys-shard-00-00.9xpvtwc.mongodb.net:27017: connection closed')>, <ServerDescription ('ac-dxhyvys-shard-00-01.9xpvtwc.mongodb.net', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('ac-dxhyvys-shard-00-01.9xpvtwc.mongodb.net:27017: connection closed')>, <ServerDescription ('ac-dxhyvys-shard-00-02.9xpvtwc.mongodb.net', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('ac-dxhyvys-shard-00-02.9xpvtwc.mongodb.net:27017: connection closed')>]>
